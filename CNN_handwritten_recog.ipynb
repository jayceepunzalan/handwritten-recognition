# %% [markdown]
# # Handwritten Classification MNIST

# %% [markdown]
# **Import necessary packages**

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.1

# %%
from tensorflow import keras
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras import Sequential

import matplotlib.pyplot as plt

# %% [markdown]
# **Load dataset**

# %%
mnist = keras.datasets.mnist

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %% [markdown]
# **Exploratory Data Analysis**

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
#plotting the first 9 train images
from matplotlib import pyplot
for i in range(9):
    plt.imshow(X_train[i].reshape(28, 28), cmap=plt.cm.binary)
#     plt.title(np.argmax(pred[i], axis=0))
    plt.show()

# %%
#Check the minimun and maximum values of X_train and X_test
import numpy as np
print("minimum value of train dataset: ", np.min(X_train))
print("maximum value of train dataset: ", np.max(X_train))
# Out:
# minimum value of train dataset:  0
# maximum value of train dataset:  255

# %%
print("minimum value of test dataset: ", np.min(X_test))
print("maximum value of test dataset: ", np.max(X_test))
# Out:
# minimum value of test dataset:  0
# maximum value of test dataset:  255

# %% [markdown]
# **Data Preprocessing**

# %%
#Change the values of X_train and X_test between 0 and 1
X_train = X_train/255.0
X_test = X_test/255.0

# %%
#Check the minimun and maximum values of X_train and X_test
import numpy as np
print("minimum value of train dataset: ", np.min(X_train))
print("maximum value of train dataset: ", np.max(X_train))
print("minimum value of test dataset: ", np.min(X_test))
print("maximum value of test dataset: ", np.max(X_test))
# Out:
# minimum value of train dataset:  0.0
# maximum value of train dataset:  1.0
# minimum value of test dataset:  0.0
# maximum value of test dataset:  1.0

# %% [markdown]
# **Build and train CNN Model**

# %%
model = Sequential()
model.add(Flatten(input_shape = (28,28)))
model.add(Dense(128, activation="relu"))
model.add(Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=100)
model.save('cnn_handwritten_recog.h5')
print("Model saved!")
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2626 - accuracy: 0.9251
# Epoch 2/100
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1142 - accuracy: 0.9669
# Epoch 3/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0776 - accuracy: 0.9766
# Epoch 4/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0576 - accuracy: 0.9824
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0447 - accuracy: 0.9861
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0347 - accuracy: 0.9894
# Epoch 7/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0271 - accuracy: 0.9917
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0218 - accuracy: 0.9932
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0187 - accuracy: 0.9943
# Epoch 10/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0150 - accuracy: 0.9954
# Epoch 11/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0125 - accuracy: 0.9961
# Epoch 12/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0107 - accuracy: 0.9965
# Epoch 13/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0094 - accuracy: 0.9972
# Epoch 14/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0091 - accuracy: 0.9973
# Epoch 15/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0078 - accuracy: 0.9978
# Epoch 16/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0048 - accuracy: 0.9987
# Epoch 17/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0074 - accuracy: 0.9976
# Epoch 18/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0064 - accuracy: 0.9981
# Epoch 19/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0050 - accuracy: 0.9986
# Epoch 20/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0057 - accuracy: 0.9981
# Epoch 21/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0053 - accuracy: 0.9981
# Epoch 22/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0048 - accuracy: 0.9985
# Epoch 23/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0054 - accuracy: 0.9982
# Epoch 24/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0037 - accuracy: 0.9987
# Epoch 25/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0036 - accuracy: 0.9989
# Epoch 26/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0054 - accuracy: 0.9982
# Epoch 27/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0034 - accuracy: 0.9988
# Epoch 28/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0036 - accuracy: 0.9990
# Epoch 29/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0053 - accuracy: 0.9982
# Epoch 30/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0031 - accuracy: 0.9991
# Epoch 31/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 32/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0026 - accuracy: 0.9991
# Epoch 33/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0025 - accuracy: 0.9993
# Epoch 34/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0051 - accuracy: 0.9984
# Epoch 35/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0030 - accuracy: 0.9991
# Epoch 36/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0032 - accuracy: 0.9990
# Epoch 37/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0031 - accuracy: 0.9990
# Epoch 38/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0034 - accuracy: 0.9988
# Epoch 39/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 40/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0040 - accuracy: 0.9987
# Epoch 41/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0012 - accuracy: 0.9997
# Epoch 42/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0039 - accuracy: 0.9986
# Epoch 43/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0026 - accuracy: 0.9992
# Epoch 44/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0026 - accuracy: 0.9991
# Epoch 45/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0024 - accuracy: 0.9992
# Epoch 46/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0030 - accuracy: 0.9991
# Epoch 47/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0018 - accuracy: 0.9995
# Epoch 48/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0025 - accuracy: 0.9992
# Epoch 49/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0023 - accuracy: 0.9991
# Epoch 50/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0022 - accuracy: 0.9994
# Epoch 51/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0027 - accuracy: 0.9991
# Epoch 52/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 53/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 54/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0027 - accuracy: 0.9992
# Epoch 55/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 56/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 57/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0025 - accuracy: 0.9992
# Epoch 58/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 59/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 60/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0033 - accuracy: 0.9989
# Epoch 61/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 62/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0018 - accuracy: 0.9995
# Epoch 63/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0025 - accuracy: 0.9993
# Epoch 64/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0024 - accuracy: 0.9992
# Epoch 65/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 66/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0034 - accuracy: 0.9990
# Epoch 67/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 5.2913e-04 - accuracy: 0.9999
# Epoch 68/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0038 - accuracy: 0.9989
# Epoch 69/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0017 - accuracy: 0.9994
# Epoch 70/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 71/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0025 - accuracy: 0.9991
# Epoch 72/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0020 - accuracy: 0.9995
# Epoch 73/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0017 - accuracy: 0.9996
# Epoch 74/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0028 - accuracy: 0.9991
# Epoch 75/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 76/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0031 - accuracy: 0.9992
# Epoch 77/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.7526e-04 - accuracy: 1.0000
# Epoch 78/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0022 - accuracy: 0.9994
# Epoch 79/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 80/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0014 - accuracy: 0.9994
# Epoch 81/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0025 - accuracy: 0.9995
# Epoch 82/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 83/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0013 - accuracy: 0.9997
# Epoch 84/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 4.1260e-04 - accuracy: 0.9999
# Epoch 85/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0038 - accuracy: 0.9990
# Epoch 86/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0013 - accuracy: 0.9995
# Epoch 87/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0017 - accuracy: 0.9996
# Epoch 88/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 89/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0020 - accuracy: 0.9996
# Epoch 90/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0035 - accuracy: 0.9991
# Epoch 91/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0010 - accuracy: 0.9996
# Epoch 92/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 93/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 94/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0012 - accuracy: 0.9997
# Epoch 95/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 9.0053e-04 - accuracy: 0.9998
# Epoch 96/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 97/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0031 - accuracy: 0.9992
# Epoch 98/100
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 99/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 100/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0019 - accuracy: 0.9995
# Model saved!

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2380 - accuracy: 0.9787

# %%
print("Test loss is: ", test_loss)
# Out:
# Test loss is:  0.23796841502189636

# %%
print("Test accuracy is: ", test_acc)
# Out:
# Test accuracy is:  0.9786999821662903

# %% [markdown]
# **Model prediction using X_test dataset**

# %%
pred = model.predict(X_test)

for i in range(9):
    plt.imshow(X_test[i].reshape(28, 28), cmap=plt.cm.binary)
    plt.title(np.argmax(pred[i], axis=0))
    plt.show()
# Out:
# 313/313 [==============================] - 1s 4ms/step
